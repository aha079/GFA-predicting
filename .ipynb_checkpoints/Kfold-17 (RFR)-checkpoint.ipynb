# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
import xlsxwriter
# Out:
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:358: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if token is '':
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:2437: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if options['min_type'] is 'min' and options['min_value'] == 0:
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:2440: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if options['max_type'] is 'max' and options['max_value'] == 0:
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:4999: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if props[i]['type'] is 'number':
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:6827: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if data_bar['bar_axis_position'] is not 'none':
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:6862: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if data_bar['bar_direction'] is 'left':
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:6865: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if data_bar['bar_direction'] is 'right':
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:6875: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if data_bar['bar_axis_position'] is 'middle':
# /usr/lib/python3/dist-packages/xlsxwriter/worksheet.py:6878: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if data_bar['bar_axis_position'] is 'none':
# /usr/lib/python3/dist-packages/xlsxwriter/chart.py:2497: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if val is 'right':
# /usr/lib/python3/dist-packages/xlsxwriter/chart.py:2500: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if val is 'left':

# %%
dataset = pd.read_csv("Final Dataset.csv",usecols = ['X1','X2','X3','X4','X7','X8','X9','X10','X12','X14','X15','X16','X17','Tg','Tx','Tl','Y'])
dataset.head(5)
workbook = xlsxwriter.Workbook('best13+3.xlsx')
worksheet = workbook.add_worksheet()

# %%
m=[]
X = dataset.iloc[:,0:16].values.astype(float)
m.append(min(X[:,0]))
m.append(max(X[:,0]))
X[:,0] = (X[:,0] - min(X[:,0]))/(max(X[:,0])-min(X[:,0]))
m.append(min(X[:,1]))
m.append(max(X[:,1]))
X[:,1] = (X[:,1] - min(X[:,1]))/(max(X[:,1])-min(X[:,1]))
m.append(min(X[:,2]))
m.append(max(X[:,2]))
X[:,2] = (X[:,2] - min(X[:,2]))/(max(X[:,2])-min(X[:,2]))
m.append(min(X[:,3]))
m.append(max(X[:,3]))
X[:,3] = (X[:,3] - min(X[:,3]))/(max(X[:,3])-min(X[:,3]))
m.append(min(X[:,4]))
m.append(max(X[:,4]))
X[:,4] = (X[:,4] - min(X[:,4]))/(max(X[:,4])-min(X[:,4]))
m.append(min(X[:,5]))
m.append(max(X[:,5]))
X[:,5] = (X[:,5] - min(X[:,5]))/(max(X[:,5])-min(X[:,5]))
m.append(min(X[:,6]))
m.append(max(X[:,6]))
X[:,6] = (X[:,6] - min(X[:,6]))/(max(X[:,6])-min(X[:,6]))
m.append(min(X[:,7]))
m.append(max(X[:,7]))
X[:,7] = (X[:,7] - min(X[:,7]))/(max(X[:,7])-min(X[:,7]))
m.append(min(X[:,8]))
m.append(max(X[:,8]))
X[:,8] = (X[:,8] - min(X[:,8]))/(max(X[:,8])-min(X[:,8]))
m.append(min(X[:,9]))
m.append(max(X[:,9]))
X[:,9] = (X[:,9] - min(X[:,9]))/(max(X[:,9])-min(X[:,9]))
m.append(min(X[:,10]))
m.append(max(X[:,10]))
X[:,10] = (X[:,10] - min(X[:,10]))/(max(X[:,10])-min(X[:,10]))
m.append(min(X[:,11]))
m.append(max(X[:,11]))
X[:,11] = (X[:,11] - min(X[:,11]))/(max(X[:,11])-min(X[:,11]))
m.append(min(X[:,12]))
m.append(max(X[:,12]))
X[:,12] = (X[:,12] - min(X[:,12]))/(max(X[:,12])-min(X[:,12]))
m.append(min(X[:,13]))
m.append(max(X[:,13]))
X[:,13] = (X[:,13] - min(X[:,13]))/(max(X[:,13])-min(X[:,13]))
m.append(min(X[:,14]))
m.append(max(X[:,14]))
X[:,14] = (X[:,14] - min(X[:,14]))/(max(X[:,14])-min(X[:,14]))
m.append(min(X[:,15]))
m.append(max(X[:,15]))
X[:,15] = (X[:,15] - min(X[:,15]))/(max(X[:,15])-min(X[:,15]))

y = dataset.iloc[:,16].values.astype(float)
#y = (y - min(y))/(max(y)-min(y))

# %%
from sklearn.svm import SVR
from sklearn.model_selection import RepeatedKFold,ShuffleSplit
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE 
from sklearn import metrics
d={
  5:0,
  10:0
}
cv = RepeatedKFold(n_splits=5, n_repeats=20, random_state=123)
count1RF=0
count2RF=0
maxR2=0
selector = RandomForestRegressor(max_depth= 21,n_estimators=36, random_state=False)
for train, test in cv.split(y):
    selector = selector.fit(X, y)
    y_pred2 = selector.predict(X[test])
    x_pred2 = selector.predict(X[train])
    R2test2=1-(((y[test] - y_pred2) ** 2).sum())/((y[test] - y[test].mean()) ** 2).sum()
    R2train2=1-(((y[train] - x_pred2) ** 2).sum())/((y[train] - y[train].mean()) ** 2).sum()
    if abs(R2train2-R2test2)*100>5:
        d[10]+=1
    else:
        d[5]+=1
    count1RF+=R2test2
    count2RF+=R2train2
    maxR2=max(maxR2,R2test2)
    if R2test2>0.95:
        plt.show()
        print("------------------------------------------------------------")
        row = 1
        col = 0
        worksheet.write(row, 0, 'test number')
        worksheet.write(row, 1, 'real value')
        worksheet.write(row, 2, 'predicted value')
        for num, real, pred in zip(test,y[test],y_pred2):
            worksheet.write(row, col,     num)
            worksheet.write(row, col + 1, real)
            worksheet.write(row, col + 2, pred)
            row += 1
        worksheet.write(row, 0, 'Train R2')
        worksheet.write(row, 1, R2train2)
        worksheet.write(row+1, 0, 'Test R2')
        worksheet.write(row+1, 1, R2test2)
        mae = metrics.mean_absolute_error(y[test], y_pred2)
        worksheet.write(row+2, 0, 'Mean absolute error')
        worksheet.write(row+2, 1, mae)
        
        print(test)
        print("predicted Value in test set with RandomForest:")
        print(y_pred2)
        print("Test accuracy result in RandomForest:",R2test2)
        print('Mean Absolute Error in RandomForest:', mae)
        print("Train accuracy result in RandomForest:",R2train2)
        print("------------------------------------------------------------")
print(maxR2)
print(d)
workbook.close()
#print(selector.support_)
#print(selector.ranking_)
print("Test accuracy average in RandomForest:",count1RF/100.0)
print("Train accuracy average in RandomForest:",count2RF/100.0)
# Out:
# ------------------------------------------------------------
# [  1   3   6  15  22  24  28  29  31  34  41  48  61  65  68  72  73  88
#   92 101 107 109 110 111 112 115 124 128 129 132 138 141 144 148 151 153
#  154 155 156 159 162 165 167 173 174 175 180 181 193 196 215 233 236 237
#  240 269 270 271 274 277 287 289 292 301 310 316 323 325 329 334 341 343
#  344 354 365 376 384 385 394 399 403 404 406 417 420 423 425 426 430 432
#  435 436 443 459 464 465 469 485 490 493 501 504 510 513 516 517 520 523
#  528 534 536 537 553 554 559 560 563 568 576 581 586 598 609 619 624 632
#  634 636 640 643 646 647 655 671 678 680 681 683 685 693 694 699 707]
# predicted Value in test set with RandomForest:
# [ 5.48611111  7.44444444  3.01990741  3.34166667 16.72222222 11.30555556
#  10.72222222  8.95061728 11.66666667  9.42222222  5.93055556  3.36111111
#  29.58333333 13.59444444  5.19444444  8.06666667 13.83333333  6.63888889
#   3.52777778  2.83333333  8.33333333 13.05555556 12.35277778  8.93055556
#   7.08333333 11.13888889  6.44444444 10.27006173  3.22222222  1.84722222
#  10.83333333  7.23611111  5.11111111 17.27777778  9.72222222  9.11111111
#   7.56944444 10.83333333  3.33888889  2.33333333  6.91666667  5.875
#  10.94444444 10.29166667 10.01388889  8.84722222  2.68055556  1.9
#   5.11111111  2.88558201  5.40740741  4.96388889  9.19166667  6.58333333
#  12.91666667  4.30555556  2.23611111  2.26666667  4.08348765  7.40277778
#   8.11111111  2.68055556  4.06944444  2.51230159  2.61111111  1.97222222
#   3.59722222  4.80555556  2.31944444  2.65674603  2.11111111  1.44444444
#   2.63888889  2.19444444  2.81944444  9.44444444  4.41666667  1.76388889
#   9.08333333  5.25        7.01388889  5.81944444  9.13888889 16.22222222
#   3.83333333  9.84722222  4.51388889  3.45277778  2.72222222  3.17916667
#   1.81388889  2.61574074  4.51388889  2.58730159  3.27777778  3.80555556
#   2.18055556  4.16666667  2.29166667  2.72222222  8.29166667 10.36111111
#   2.19444444  1.48611111  2.55555556  3.45        3.51944444  6.65277778
#   3.26388889  3.08101852  2.65277778  3.72222222  6.98611111 19.58333333
#  25.5        29.58333333  4.05        6.83333333  6.44444444  7.01666667
#   2.55555556  7.61111111  3.72222222  9.61111111  5.84722222  5.98611111
#   4.73611111  3.25        2.19444444  4.28240741  5.18055556  2.5
#   6.91666667  7.84722222  8.27777778  3.1125      1.80555556  1.61111111
#   2.40277778  8.11111111  3.58333333  3.41666667 10.52222222]
# Test accuracy result in RandomForest: 0.950134509159715
# Mean Absolute Error in RandomForest: 0.8853413561746896
# Train accuracy result in RandomForest: 0.8994616451191022
# ------------------------------------------------------------
# 0.950134509159715
# {5: 40, 10: 5}
# Test accuracy average in RandomForest: 0.4066823313887521
# Train accuracy average in RandomForest: 0.4081513327130156
